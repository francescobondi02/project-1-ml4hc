# %% [markdown]
# # Q1.3 - Data Preprocessing

# %% [markdown]
# ### First we need to load the data

# %%
# Load data from parquet file
import pandas as pd
import numpy as np
from project_1.config import PROJ_ROOT, PROCESSED_DATA_DIR

sets_dict = {}
sets = ["a", "b", "c"]

for set_name in sets:
    directory = PROCESSED_DATA_DIR / f"set_{set_name}.parquet"
    temp_set = pd.read_parquet(directory)
    sets_dict[f"set_{set_name}"] = temp_set

# Assure the loading was correct
print(sets_dict["set_a"].shape)
sets_dict["set_a"].head(10)
# Out:
# (183416, 43)
#    RecordID                Time   Age  BUN  Creatinine   GCS  Gender  Glucose  \
# 0  132539.0 2025-03-10 00:00:00  54.0  NaN         NaN   NaN     0.0      NaN
# 1  132539.0 2025-03-10 01:00:00   NaN  NaN         NaN  15.0     NaN      NaN
# 2  132539.0 2025-03-10 02:00:00   NaN  NaN         NaN   NaN     NaN      NaN
# 3  132539.0 2025-03-10 03:00:00   NaN  NaN         NaN   NaN     NaN      NaN
# 4  132539.0 2025-03-10 04:00:00   NaN  NaN         NaN  15.0     NaN      NaN
# 5  132539.0 2025-03-10 05:00:00   NaN  NaN         NaN   NaN     NaN      NaN
# 6  132539.0 2025-03-10 06:00:00   NaN  NaN         NaN   NaN     NaN      NaN
# 7  132539.0 2025-03-10 08:00:00   NaN  NaN         NaN  15.0     NaN      NaN
# 8  132539.0 2025-03-10 09:00:00   NaN  NaN         NaN   NaN     NaN      NaN
# 9  132539.0 2025-03-10 10:00:00   NaN  NaN         NaN   NaN     NaN      NaN
#
#    HCO3   HCT  ...  PaCO2  PaO2  pH  DiasABP  MAP  SaO2  SysABP  Lactate  \
# 0   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 1   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 2   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 3   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 4   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 5   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 6   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 7   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 8   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 9   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
#
#    Cholesterol  TroponinI
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# ## Step 1 - Use Forward Filling imputation (use only Set A for now)

# %%
df = sets_dict["set_a"]

# Ensure the DataFrame is sorted by RecordID and Time
df.sort_values(by=["RecordID", "Time"], inplace=True)

# Get a list of all columns except "RecordID" and "Time"
other_cols = [col for col in df.columns if col != "RecordID" and col != "Time"]

# Group by RecordID and apply forward fill for each group.
df[other_cols] = df.groupby("RecordID")[other_cols].ffill()

# Display the first 10 rows to check the result
df.head(10)
# Out:
#    RecordID                Time   Age  BUN  Creatinine   GCS  Gender  Glucose  \
# 0  132539.0 2025-03-10 00:00:00  54.0  NaN         NaN   NaN     0.0      NaN
# 1  132539.0 2025-03-10 01:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 2  132539.0 2025-03-10 02:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 3  132539.0 2025-03-10 03:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 4  132539.0 2025-03-10 04:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 5  132539.0 2025-03-10 05:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 6  132539.0 2025-03-10 06:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 7  132539.0 2025-03-10 08:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 8  132539.0 2025-03-10 09:00:00  54.0  NaN         NaN  15.0     0.0      NaN
# 9  132539.0 2025-03-10 10:00:00  54.0  NaN         NaN  15.0     0.0      NaN
#
#    HCO3   HCT  ...  PaCO2  PaO2  pH  DiasABP  MAP  SaO2  SysABP  Lactate  \
# 0   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 1   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 2   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 3   NaN   NaN  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 4   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 5   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 6   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 7   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 8   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
# 9   NaN  33.7  ...    NaN   NaN NaN      NaN  NaN   NaN     NaN      NaN
#
#    Cholesterol  TroponinI
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# ### Success, the values are being forwarded. Keep in mind that this can be altered in the future

# %% [markdown]
# # Step 2 - Scale the data
